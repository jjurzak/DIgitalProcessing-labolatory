# %% [markdown]
# ## 1. Load a Grayscale Image and Compute its 2D Fourier Transform
#
# To analyze an image in the frequency domain, we first need to compute its 2D Discrete Fourier Transform (DFT).

# %%
#! pip install opencv-python

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Load image in grayscale
image = cv2.imread('checkerboard.png', cv2.IMREAD_GRAYSCALE)

# Compute 2D FFT
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)  # Shift zero freq. to center

# %% [markdown]
# ## 2 Visualize the Magnitude Spectrum of the Image
#
# The magnitude spectrum highlights frequency components of the image. Use a logarithmic scale to better visualize differences.

# %%
# Compute magnitude spectrum
magnitude_spectrum = 20 * np.log(np.abs(fshift) + 1)

plt.figure(figsize=(6,6))
plt.imshow(magnitude_spectrum, cmap='gray')
plt.title('Magnitude Spectrum')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 3 Apply a Low-Pass and High-Pass Filter in the Frequency Domain
#
# Create a mask in the frequency domain to filter out high or low frequencies.

# %%
rows, cols = image.shape
crow, ccol = rows // 2 , cols // 2

# Create a low-pass filter mask (circle in the center)
mask_lp = np.zeros((rows, cols), np.uint8)
r = 50  # Radius
cv2.circle(mask_lp, (ccol, crow), r, 1, thickness=-1)

# Create high-pass mask as complement
mask_hp = 1 - mask_lp

# Apply the masks
fshift_lp = fshift * mask_lp
fshift_hp = fshift * mask_hp

# %% [markdown]
# ## 4 Reconstruct the Image from the Filtered Spectrum
#
# To get the filtered image, apply the inverse Fourier transform.

# %%
# Inverse shift and IFFT for low-pass
f_ishift_lp = np.fft.ifftshift(fshift_lp)
img_back_lp = np.fft.ifft2(f_ishift_lp)
img_back_lp = np.abs(img_back_lp)

# Display the result
plt.imshow(img_back_lp, cmap='gray')
plt.title('Low-Pass Filtered Image')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 5 Load an Audio Signal and Compute its Spectrogram
#
# Use the Librosa library to load an audio file and compute the spectrogram using STFT.

# %%
pip install librosa

# %%
import librosa
import librosa.display

# Load audio file
y, sr = librosa.load('sine_sweep.wav', sr=None)

# Compute STFT
D = librosa.stft(y)
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)

# Display spectrogram
plt.figure(figsize=(10, 4))
librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='hz', cmap='magma')
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\lowering.py:511, in Lower.lower_inst(self, inst)
#     510 try:
# --> 511     impl = self.context.get_function('static_setitem', signature)
#     512 except NotImplementedError:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\base.py:556, in BaseContext.get_function(self, fn, sig, _firstcall)
#     555     self.refresh()
# --> 556     return self.get_function(fn, sig, _firstcall=False)
#     558 raise NotImplementedError("No definition for lowering %s%s" % (key, sig))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\base.py:558, in BaseContext.get_function(self, fn, sig, _firstcall)
#     556     return self.get_function(fn, sig, _firstcall=False)
# --> 558 raise NotImplementedError("No definition for lowering %s%s" % (key, sig))
#
# NotImplementedError: No definition for lowering static_setitem(Array(bool, 1, 'A', False, aligned=True), slice<a:b>, Array(bool, 1, 'A', False, aligned=True)) -> none
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 5
#       2 import librosa.display
#       4 # Load audio file
# ----> 5 y, sr = librosa.load('sine_sweep.wav', sr=None)
#       7 # Compute STFT
#       8 D = librosa.stft(y)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\lazy_loader\__init__.py:83, in attach.<locals>.__getattr__(name)
#      81 submod_path = f"{package_name}.{attr_to_modules[name]}"
#      82 submod = importlib.import_module(submod_path)
# ---> 83 attr = getattr(submod, name)
#      85 # If the attribute lives in a file (module) with the same
#      86 # name as the attribute, ensure that the attribute and *not*
#      87 # the module is accessible on the package.
#      88 if name == attr_to_modules[name]:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\lazy_loader\__init__.py:82, in attach.<locals>.__getattr__(name)
#      80 elif name in attr_to_modules:
#      81     submod_path = f"{package_name}.{attr_to_modules[name]}"
# ---> 82     submod = importlib.import_module(submod_path)
#      83     attr = getattr(submod, name)
#      85     # If the attribute lives in a file (module) with the same
#      86     # name as the attribute, ensure that the attribute and *not*
#      87     # the module is accessible on the package.
#
# File c:\Program Files\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1206, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1178, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1149, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\librosa\core\audio.py:1154
#    1150     else:
#    1151         return np.sign(x0) != np.sign(x1)  # type: ignore
# -> 1154 @guvectorize(
#    1155     [
#    1156         "void(float32[:], float32, bool_, bool_[:])",
#    1157         "void(float64[:], float64, bool_, bool_[:])",
#    1158     ],
#    1159     "(n),(),()->(n)",
#    1160     cache=True,
#    1161     nopython=True,
#    1162 )  # type: ignore
#    1163 def _zc_wrapper(
#    1164     x: np.ndarray,
#    1165     threshold: float,
#    1166     zero_pos: bool,
#    1167     y: np.ndarray,
#    1168 ) -> None:  # pragma: no cover
#    1169     """Vectorized wrapper for zero crossing stencil"""
#    1170     y[:] = _zc_stencil(x, threshold, zero_pos)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\ufunc\decorators.py:203, in guvectorize.<locals>.wrap(func)
#     201 guvec = GUVectorize(func, signature, **kwargs)
#     202 for fty in ftylist:
# --> 203     guvec.add(fty)
#     204 if len(ftylist) > 0:
#     205     guvec.disable_compile()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\ufunc\gufunc.py:137, in GUFunc.add(self, fty)
#     136 def add(self, fty):
# --> 137     self.gufunc_builder.add(fty)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\ufunc\ufuncbuilder.py:257, in _BaseUFuncBuilder.add(self, sig)
#     255 else:
#     256     targetoptions = self.nb_func.targetoptions
# --> 257 cres, args, return_type = _compile_element_wise_function(
#     258     self.nb_func, targetoptions, sig)
#     259 sig = self._finalize_signature(cres, args, return_type)
#     260 self._sigs.append(sig)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\ufunc\ufuncbuilder.py:175, in _compile_element_wise_function(nb_func, targetoptions, sig)
#     172 def _compile_element_wise_function(nb_func, targetoptions, sig):
#     173     # Do compilation
#     174     # Return CompileResult to test
# --> 175     cres = nb_func.compile(sig, **targetoptions)
#     176     args, return_type = sigutils.normalize_signature(sig)
#     177     return cres, args, return_type
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\ufunc\ufuncbuilder.py:123, in UFuncDispatcher.compile(self, sig, locals, **targetoptions)
#     118 # Disable loop lifting
#     119 # The feature requires a real
#     120 #  python function
#     121 flags.enable_looplift = False
# --> 123 return self._compile_core(sig, flags, locals)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\ufunc\ufuncbuilder.py:156, in UFuncDispatcher._compile_core(self, sig, flags, locals)
#     154 # Compile
#     155 args, return_type = sigutils.normalize_signature(sig)
# --> 156 cres = compiler.compile_extra(typingctx, targetctx,
#     157                               self.py_func, args=args,
#     158                               return_type=return_type,
#     159                               flags=flags, locals=locals)
#     161 # cache lookup failed before so safe to save
#     162 self.cache.save_overload(sig, cres)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:481, in CompilerBase._compile_core(self)
#     479 except Exception as e:
#     480     if not isinstance(e, errors.NumbaError):
# --> 481         raise e
#     482     self.state.status.fail_reason = e
#     483     if is_final_pipeline:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_machinery.py:363, in PassManager.run(self, state)
#     361 except Exception as e:
#     362     if not isinstance(e, errors.NumbaError):
# --> 363         raise e
#     364     msg = "Failed in %s mode pipeline (step: %s)" % \
#     365         (self.pipeline_name, pass_desc)
#     366     patched_exception = self._patch_error(msg, e)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\typed_passes.py:468, in BaseNativeLowering.run_pass(self, state)
#     465 with targetctx.push_code_library(library):
#     466     lower = self.lowering_class(targetctx, library, fndesc, interp,
#     467                                 metadata=metadata)
# --> 468     lower.lower()
#     469     if not flags.no_cpython_wrapper:
#     470         lower.create_cpython_wrapper(flags.release_gil)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\lowering.py:193, in BaseLower.lower(self)
#     191 if self.generator_info is None:
#     192     self.genlower = None
# --> 193     self.lower_normal_function(self.fndesc)
#     194 else:
#     195     self.genlower = self.GeneratorLower(self)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\lowering.py:232, in BaseLower.lower_normal_function(self, fndesc)
#     230 # Init argument values
#     231 self.extract_function_arguments()
# --> 232 entry_block_tail = self.lower_function_body()
#     234 # Close tail of entry block, do not emit debug metadata else the
#     235 # unconditional jump gets associated with the metadata from the function
#     236 # body end.
#     237 with debuginfo.suspend_emission(self.builder):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\lowering.py:262, in BaseLower.lower_function_body(self)
#     260     self.builder.position_at_end(bb)
#     261     self.debug_print(f"# lower block: {offset}")
# --> 262     self.lower_block(block)
#     263 self.post_lower()
#     264 return entry_block_tail
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\lowering.py:276, in BaseLower.lower_block(self, block)
#     273     defaulterrcls = partial(LoweringError, loc=self.loc)
#     274     with new_error_context('lowering "{inst}" at {loc}', inst=inst,
#     275                            loc=self.loc, errcls_=defaulterrcls):
# --> 276         self.lower_inst(inst)
#     277 self.post_block(block)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\lowering.py:513, in Lower.lower_inst(self, inst)
#     511     impl = self.context.get_function('static_setitem', signature)
#     512 except NotImplementedError:
# --> 513     return self.lower_setitem(inst.target, inst.index_var,
#     514                               inst.value, signature)
#     515 else:
#     516     target = self.loadvar(inst.target.name)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\lowering.py:624, in Lower.lower_setitem(self, target_var, index_var, value_var, signature)
#     619 index = self.context.cast(self.builder, index, indexty,
#     620                           signature.args[1])
#     621 value = self.context.cast(self.builder, value, valuety,
#     622                           signature.args[2])
# --> 624 return impl(self.builder, (target, index, value))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\base.py:1190, in _wrap_impl.__call__(self, builder, args, loc)
#    1189 def __call__(self, builder, args, loc=None):
# -> 1190     res = self._imp(self._context, builder, self._sig, args, loc=loc)
#    1191     self._context.add_linking_libs(getattr(self, 'libs', ()))
#    1192     return res
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\base.py:1220, in _wrap_missing_loc.__call__.<locals>.wrapper(*args, **kwargs)
#    1218 def wrapper(*args, **kwargs):
#    1219     kwargs.pop('loc')     # drop unused loc
# -> 1220     return fn(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\arrayobj.py:556, in setitem_array(context, builder, sig, args)
#     551     use_fancy_indexing = bool(shapes)
#     553 if use_fancy_indexing:
#     554     # Index describes a non-trivial view => use generic slice assignment
#     555     # (NOTE: this also handles scalar broadcasting)
# --> 556     return fancy_setslice(context, builder, sig, args,
#     557                           index_types, indices)
#     559 # Store source value the given location
#     560 val = context.cast(builder, val, valty, aryty.dtype)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\arrayobj.py:1719, in fancy_setslice(context, builder, sig, args, index_types, indices)
#    1715     shape_error = builder.or_(shape_error,
#    1716                               builder.icmp_signed('!=', u, v))
#    1718 with builder.if_then(shape_error, likely=False):
# -> 1719     raise_shape_mismatch_error(context, builder, src_shapes,
#    1720                                index_shape)
#    1722 # Check for array overlap
#    1723 src_start, src_end = get_array_memory_extents(context, builder, srcty,
#    1724                                               src, src_shapes,
#    1725                                               src_strides, src_data)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\np\arrayobj.py:1691, in fancy_setslice.<locals>.raise_shape_mismatch_error(context, builder, src_shapes, index_shape)
#    1687 fnty = context.typing_context.resolve_value_type(
#    1688     raise_with_shape_context)
#    1689 argtys = (types.UniTuple(types.int64, len(src_shapes)),
#    1690           types.UniTuple(types.int64, len(index_shape)))
# -> 1691 raise_sig = fnty.get_call_type(context.typing_context, argtys, {})
#    1692 func = context.get_function(fnty, raise_sig)
#    1693 func(builder, (context.make_tuple(builder, raise_sig.args[0],
#    1694                                   src_shapes),
#    1695                context.make_tuple(builder, raise_sig.args[1],
#    1696                                   index_shape)))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\types\functions.py:311, in BaseFunction.get_call_type(self, context, args, kws)
#     309 except Exception as e:
#     310     if not isinstance(e, errors.NumbaError):
# --> 311         raise e
#     312     sig = None
#     313     failures.add_error(temp, False, e, uselit)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\types\functions.py:308, in BaseFunction.get_call_type(self, context, args, kws)
#     305         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     306         nolitkws = {k: _unlit_non_poison(v)
#     307                     for k, v in kws.items()}
# --> 308         sig = temp.apply(nolitargs, nolitkws)
#     309 except Exception as e:
#     310     if not isinstance(e, errors.NumbaError):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\typing\templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\typing\templates.py:621, in _OverloadFunctionTemplate.generic(self, args, kws)
#     615 """
#     616 Type the overloaded function by compiling the appropriate
#     617 implementation for the given args.
#     618 """
#     619 from numba.core.typed_passes import PreLowerStripPhis
# --> 621 disp, new_args = self._get_impl(args, kws)
#     622 if disp is None:
#     623     return
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\typing\templates.py:720, in _OverloadFunctionTemplate._get_impl(self, args, kws)
#     716 except KeyError:
#     717     # pass and try outside the scope so as to not have KeyError with a
#     718     # nested addition error in the case the _build_impl fails
#     719     pass
# --> 720 impl, args = self._build_impl(cache_key, args, kws)
#     721 return impl, args
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\typing\templates.py:824, in _OverloadFunctionTemplate._build_impl(self, cache_key, args, kws)
#     822 # Make sure that the implementation can be fully compiled
#     823 disp_type = types.Dispatcher(disp)
# --> 824 disp_type.get_call_type(self.context, args, kws)
#     825 if cache_key is not None:
#     826     self._impl_cache[cache_key] = disp, args
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\types\functions.py:538, in Dispatcher.get_call_type(self, context, args, kws)
#     531 def get_call_type(self, context, args, kws):
#     532     """
#     533     Resolve a call to this dispatcher using the given argument types.
#     534     A signature returned and it is ensured that a compiled specialization
#     535     is available for it.
#     536     """
#     537     template, pysig, args, kws = \
# --> 538         self.dispatcher.get_call_template(args, kws)
#     539     sig = template(context).apply(args, kws)
#     540     if sig:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\dispatcher.py:319, in _DispatcherBase.get_call_template(self, args, kws)
#     317 # Ensure an overload is available
#     318 if self._can_compile:
# --> 319     self.compile(tuple(args))
#     321 # Create function type for typing
#     322 func_name = self.py_func.__name__
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\dispatcher.py:904, in Dispatcher.compile(self, sig)
#     902 with ev.trigger_event("numba:compile", data=ev_details):
#     903     try:
# --> 904         cres = self._compiler.compile(args, return_type)
#     905     except errors.ForceLiteralArg as e:
#     906         def folded(args, kws):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:481, in CompilerBase._compile_core(self)
#     479 except Exception as e:
#     480     if not isinstance(e, errors.NumbaError):
# --> 481         raise e
#     482     self.state.status.fail_reason = e
#     483     if is_final_pipeline:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_machinery.py:363, in PassManager.run(self, state)
#     361 except Exception as e:
#     362     if not isinstance(e, errors.NumbaError):
# --> 363         raise e
#     364     msg = "Failed in %s mode pipeline (step: %s)" % \
#     365         (self.pipeline_name, pass_desc)
#     366     patched_exception = self._patch_error(msg, e)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\untyped_passes.py:206, in InlineClosureLikes.run_pass(self, state)
#     200 from numba.core.inline_closurecall import InlineClosureCallPass
#     201 inline_pass = InlineClosureCallPass(
#     202     state.func_ir,
#     203     state.flags.auto_parallel,
#     204     state.parfor_diagnostics.replaced_fns,
#     205     typed_pass)
# --> 206 inline_pass.run()
#     208 # Remove all Dels, and re-run postproc
#     209 post_proc = postproc.PostProcessor(state.func_ir)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\inline_closurecall.py:114, in InlineClosureCallPass.run(self)
#     111     modified = True
#     112     break # because block structure changed
# --> 114 if guard(self._inline_closure,
#     115          work_list, block, i, func_def):
#     116     modified = True
#     117     break # because block structure changed
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\ir_utils.py:1583, in guard(func, *args, **kwargs)
#    1577 """
#    1578 Run a function with given set of arguments, and guard against
#    1579 any GuardException raised by the function by returning None,
#    1580 or the expected return results if no such exception was raised.
#    1581 """
#    1582 try:
# -> 1583     return func(*args, **kwargs)
#    1584 except GuardException:
#    1585     return None
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\inline_closurecall.py:271, in InlineClosureCallPass._inline_closure(self, work_list, block, i, func_def)
#     268 def _inline_closure(self, work_list, block, i, func_def):
#     269     require(isinstance(func_def, ir.Expr) and
#     270             func_def.op == "make_function")
# --> 271     inline_closure_call(self.func_ir,
#     272                         self.func_ir.func_id.func.__globals__,
#     273                         block, i, func_def, work_list=work_list,
#     274                         callee_validator=callee_ir_validator)
#     275     return True
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\inline_closurecall.py:613, in inline_closure_call(func_ir, glbls, block, i, callee, typingctx, targetctx, arg_typs, typemap, calltypes, work_list, callee_validator, replace_freevars)
#     611     callee_ir = compiler.run_frontend(callee, inline_closures=True)
#     612 else:
# --> 613     callee_ir = get_ir_of_code(glbls, callee_code)
#     615 # check that the contents of the callee IR is something that can be inlined
#     616 # if a validator is supplied
#     617 if callee_validator is not None:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\numba\core\ir_utils.py:1822, in get_ir_of_code(glbls, fcode)
#    1820 swapped = {} # TODO: get this from diagnostics store
#    1821 import numba.core.inline_closurecall
# -> 1822 inline_pass = numba.core.inline_closurecall.InlineClosureCallPass(
#    1823     ir, numba.core.cpu.ParallelOptions(False), swapped)
#    1824 inline_pass.run()
#    1826 # TODO: DO NOT ADD MORE THINGS HERE!
#    1827 # If adding more things here is being contemplated, it really is time to
#    1828 # retire this function and work on getting the InlineWorker class from
#    (...)   1833
#    1834 # rebuild IR in SSA form
#
# AttributeError: module 'numba' has no attribute 'core'

# %% [markdown]
# ## 6 Compare Time-Domain and Frequency-Domain Representations
#
# Plot both the waveform and its corresponding frequency representation.

# %%
# Plot waveform (time domain)
plt.figure()
librosa.display.waveshow(y, sr=sr)
plt.title('Time Domain Signal')

# Plot magnitude spectrum (frequency domain)
Y = np.fft.fft(y)
freqs = np.fft.fftfreq(len(Y), 1/sr)
plt.figure()
plt.plot(freqs[:len(freqs)//2], np.abs(Y[:len(Y)//2]))
plt.title('Frequency Domain Signal')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 # Plot waveform (time domain)
#       2 plt.figure()
# ----> 3 librosa.display.waveshow(y, sr=sr)
#       4 plt.title('Time Domain Signal')
#       6 # Plot magnitude spectrum (frequency domain)
#
# NameError: name 'y' is not defined

# %% [markdown]
# ## 7 (Optional) Apply a Denoising Filter Using Frequency Domain Processing
#
# Simple denoising can be performed by suppressing very high-frequency components.

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Load image in grayscale
image = cv2.imread('PNG_transparency_demonstration_1.png', cv2.IMREAD_GRAYSCALE)
if image is None:
    raise ValueError("Image not found. Check the file path.")

# Compute 2D FFT and shift zero frequency to the center
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)

# Create a low-pass mask
rows, cols = image.shape
crow, ccol = rows // 2, cols // 2
r = 50  # radius of the low-pass circle

# Create a float32 mask (same shape, values between 0 and 1)
mask_lp = np.zeros((rows, cols), dtype=np.float32)
cv2.circle(mask_lp, (ccol, crow), r, 1, thickness=-1)

# Apply mask to the shifted FFT
fshift_lp = fshift * mask_lp

# Inverse shift and inverse FFT to reconstruct image
f_ishift = np.fft.ifftshift(fshift_lp)
img_back = np.fft.ifft2(f_ishift)
img_back = np.abs(img_back)  # Get magnitude (real part only)

# Display original and filtered image
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_back, cmap='gray')
plt.title('Low-Pass Filtered Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Band-Pass Filter for Image

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# Load image in grayscale
image = cv2.imread('PNG_transparency_demonstration_1.png', cv2.IMREAD_GRAYSCALE)
if image is None:
    raise ValueError("Image not found. Check the file path.")

# Compute 2D FFT and shift zero frequency to the center
f = np.fft.fft2(image)
fshift = np.fft.fftshift(f)

# Get dimensions and center
rows, cols = image.shape
crow, ccol = rows // 2, cols // 2

# Define inner and outer radii for the band-pass filter
r1 = 20   # Inner radius (removes low frequencies)
r2 = 80   # Outer radius (removes high frequencies)

# Create band-pass mask: circle ring between r1 and r2
mask = np.zeros((rows, cols), dtype=np.float32)
cv2.circle(mask, (ccol, crow), r2, 1, thickness=-1)    # Outer circle (everything inside is 1)
cv2.circle(mask, (ccol, crow), r1, 0, thickness=-1)    # Inner circle (set center to 0 again)

# Apply the band-pass filter
fshift_bp = fshift * mask

# Inverse shift and inverse FFT to reconstruct image
f_ishift = np.fft.ifftshift(fshift_bp)
img_bandpass = np.fft.ifft2(f_ishift)
img_bandpass = np.abs(img_bandpass)

# Display results
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img_bandpass, cmap='gray')
plt.title('Band-Pass Filtered Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Appendix

# %%
import numpy as np
import cv2
from scipy.signal import chirp
from scipy.io.wavfile import write

# %% [markdown]
# ## 1. Checkerboard Image and Sine Sweep

# %%
# Image: Checkerboard
def generate_checkerboard(size=256, squares=8):
    block = np.kron([[1, 0] * (squares // 2), [0, 1] * (squares // 2)] * (squares // 2),
                    np.ones((size//squares, size//squares)))
    cv2.imwrite('checkerboard.png', (block * 255).astype(np.uint8))

# Audio: Sine sweep
def generate_sine_sweep(f0=100, f1=2000, duration=5, fs=44100):
    t = np.linspace(0, duration, int(fs * duration))
    y = chirp(t, f0=f0, f1=f1, t1=duration, method='linear')
    write('sine_sweep.wav', fs, (y * 32767).astype(np.int16))
    
generate_checkerboard()
generate_sine_sweep()

# %% [markdown]
# ## 2. Shapes Image and Beep Pattern

# %%
# Image: Geometric shapes
def generate_shapes(size=256):
    img = np.zeros((size, size), dtype=np.uint8)
    cv2.rectangle(img, (30, 30), (100, 100), 255, -1)
    cv2.circle(img, (180, 80), 40, 255, -1)
    cv2.line(img, (50, 200), (200, 220), 255, 3)
    cv2.imwrite('shapes.png', img)

# Audio: Repeated beeps
def generate_beep(fs=44100):
    t_beep = np.linspace(0, 0.2, int(fs * 0.2))
    beep = 0.5 * np.sin(2 * np.pi * 1000 * t_beep)
    silence = np.zeros(int(fs * 0.2))
    signal = np.tile(np.concatenate((beep, silence)), 10)
    write('beep_pattern.wav', fs, (signal * 32767).astype(np.int16))

# %% [markdown]
# ## 3. Barcode Image and White Noise

# %%
# Image: Barcode
def generate_barcode(rows=256, cols=256, bars=60):
    img = np.ones((rows, cols), dtype=np.uint8) * 255
    for i in range(0, cols, cols // bars):
        cv2.rectangle(img, (i, 0), (i + cols // (2 * bars), rows), 0, -1)
    cv2.imwrite('barcode.png', img)

generate_barcode(rows=256, cols=256, bars=60)    
    
# Audio: White noise
def generate_white_noise(duration=5, fs=44100):
    noise = np.random.normal(0, 1, int(fs * duration))
    write('white_noise.wav', fs, (noise * 32767).astype(np.int16))

# %% [markdown]
# ## 4. Blurred Dot and Low-Frequency Hum

# %%
from scipy.ndimage import gaussian_filter

# Image: Blurred dot
def generate_blurred_dot(size=256):
    img = np.zeros((size, size))
    img[size//2, size//2] = 1
    blurred = gaussian_filter(img, sigma=10)
    cv2.imwrite('blurred_dot.png', (blurred * 255).astype(np.uint8))

# Audio: 50Hz hum
def generate_hum(freq=50, duration=5, fs=44100):
    t = np.linspace(0, duration, int(fs * duration))
    y = 0.5 * np.sin(2 * np.pi * freq * t)
    write('hum.wav', fs, (y * 32767).astype(np.int16))

# %% [markdown]
# ## 5. Ring Image and Harmonic Tones

# %%
# Image: Ring
def generate_ring(size=256):
    img = np.zeros((size, size), dtype=np.uint8)
    cv2.circle(img, (size//2, size//2), 60, 255, thickness=5)
    cv2.imwrite('ring.png', img)

# Audio: 440 Hz and 880 Hz
def generate_harmonics(fs=44100, duration=3):
    t = np.linspace(0, duration, int(fs * duration))
    y = 0.5 * np.sin(2 * np.pi * 440 * t) + 0.5 * np.sin(2 * np.pi * 880 * t)
    write('harmonics.wav', fs, (y * 32767).astype(np.int16))

# %% [markdown]
# ## 6. Diagonal Stripes and Square Wave

# %%
# Diagonal stripes
def generate_diagonal_stripes(size=256, spacing=20):
    img = np.zeros((size, size), dtype=np.uint8)
    for i in range(0, size, spacing):
        cv2.line(img, (i, 0), (0, i), 255, 1)
    cv2.imwrite('diagonal_stripes.png', img)

# Square wave audio
from scipy.signal import square
def generate_square_wave(freq=500, duration=3, fs=44100):
    t = np.linspace(0, duration, int(fs * duration))
    y = 0.5 * square(2 * np.pi * freq * t)
    write('square_wave.wav', fs, (y * 32767).astype(np.int16))

# %% [markdown]
# ## 7. Random Noise Image and AM Sine Wave

# %%
# Image: Smoothed noise
def generate_smoothed_noise(size=256):
    from scipy.ndimage import gaussian_filter
    noise = np.random.rand(size, size)
    smooth = gaussian_filter(noise, sigma=10)
    cv2.imwrite('smoothed_noise.png', (smooth * 255).astype(np.uint8))

# Audio: AM (Amplitude Modulation)
def generate_am_signal(fs=44100, duration=5):
    t = np.linspace(0, duration, int(fs * duration))
    carrier = np.sin(2 * np.pi * 1000 * t)
    modulator = (1 + np.sin(2 * np.pi * 5 * t)) / 2
    y = carrier * modulator
    write('am_signal.wav', fs, (y * 32767).astype(np.int16))

# %% [markdown]
# ## 8. Fractal Noise and Impulse Train

# %%
# Image: Fractal-like noise
def generate_fractal_noise(size=256):
    from scipy.ndimage import gaussian_filter
    noise = gaussian_filter(np.random.rand(size, size), sigma=8)
    cv2.imwrite('fractal_noise.png', (noise * 255).astype(np.uint8))

# Audio: Repeating impulses
def generate_impulse_train(fs=44100, duration=5, interval=1):
    signal = np.zeros(int(fs * duration))
    for i in range(0, int(duration), interval):
        signal[i * fs] = 1.0
    write('impulse_train.wav', fs, (signal * 32767).astype(np.int16))

# %% [markdown]
# ## 9. Grid Pattern and Fading Sine Wave

# %%
# Image: Grid with gaps
def generate_broken_grid(size=256, step=32):
    img = np.zeros((size, size), dtype=np.uint8)
    for i in range(0, size, step):
        if i % 64 != 0:
            img[i, :] = 255
            img[:, i] = 255
    cv2.imwrite('broken_grid.png', img)

# Audio: Fade-in sine
def generate_fadein_sine(fs=44100, duration=5, freq=440):
    t = np.linspace(0, duration, int(fs * duration))
    envelope = np.linspace(0, 1, len(t))
    y = envelope * np.sin(2 * np.pi * freq * t)
    write('fadein_sine.wav', fs, (y * 32767).astype(np.int16))

# %% [markdown]
# ## 10. Symmetric Shapes and Alternating Noise

# %%
# Image: Symmetric pattern
def generate_symmetric_shapes(size=256):
    img = np.zeros((size, size), dtype=np.uint8)
    cv2.circle(img, (size//4, size//2), 30, 255, -1)
    cv2.circle(img, (3*size//4, size//2), 30, 255, -1)
    cv2.line(img, (size//2, 0), (size//2, size), 255, 2)
    cv2.imwrite('symmetric_shapes.png', img)

# Audio: Alternating noise and silence
def generate_onoff_noise(fs=44100, duration=5):
    noise = np.random.normal(0, 0.5, fs//2)
    silence = np.zeros(fs//2)
    pattern = np.tile(np.concatenate([noise, silence]), duration // 1)
    write('onoff_noise.wav', fs, (pattern * 32767).astype(np.int16))

# %% [markdown]
# ## 11. Horizontal Edge and Pulse Train

# %%
# Image: Half black, half white
def generate_edge_image(size=256):
    img = np.zeros((size, size), dtype=np.uint8)
    img[:, size//2:] = 255
    cv2.imwrite('half_edge.png', img)

# Audio: Pulse train
def generate_pulse_train(fs=44100, duration=5):
    signal = np.zeros(int(fs * duration))
    for i in range(0, len(signal), fs//10):
        signal[i:i+10] = 1
    write('pulse_train.wav', fs, (signal * 32767).astype(np.int16))

# %% [markdown]
# ## 12. Triangle Image and Triangle Wave Audio

# %%
from scipy.signal import sawtooth

# Image: Triangle waveform pattern (horizontal)
def generate_triangle_pattern(size=256):
    img = np.tile(np.linspace(0, 255, size, dtype=np.uint8), (size, 1))
    triangle = np.abs((img.astype(float) - 127.5) * 2)
    cv2.imwrite('triangle_pattern.png', triangle.astype(np.uint8))

# Audio: Triangle wave
def generate_triangle_wave(freq=500, duration=3, fs=44100):
    t = np.linspace(0, duration, int(fs * duration))
    y = 0.5 * sawtooth(2 * np.pi * freq * t, 0.5)
    write('triangle_wave.wav', fs, (y * 32767).astype(np.int16))

# %% [markdown]
# ## 13. Vertical Line and High-Frequency Burst

# %%
# Image: Vertical line in center
def generate_vertical_line(size=256):
    img = np.zeros((size, size), dtype=np.uint8)
    img[:, size//2] = 255
    cv2.imwrite('vertical_line.png', img)

# Audio: High-frequency burst
def generate_burst(fs=44100, duration=2, freq=3000):
    t = np.linspace(0, duration, int(fs * duration))
    y = np.zeros_like(t)
    y[:fs//5] = 0.5 * np.sin(2 * np.pi * freq * t[:fs//5])
    write('burst.wav', fs, (y * 32767).astype(np.int16))

# %% [markdown]
# ## 14. Gradient and Chirp

# %%
# Image: Horizontal gradient
def generate_gradient(size=256):
    img = np.tile(np.linspace(0, 255, size, dtype=np.uint8), (size, 1))
    cv2.imwrite('gradient.png', img)

# Audio: Linear chirp
def generate_chirp(f0=100, f1=8000, duration=3, fs=44100):
    from scipy.signal import chirp
    t = np.linspace(0, duration, int(fs * duration))
    y = chirp(t, f0=f0, f1=f1, t1=duration, method='linear')
    write('chirp.wav', fs, (y * 32767).astype(np.int16))

# %% [markdown]
# ## 15. Overlapping Shapes and Tone + Noise

# %%
# Image: Overlapping shapes
def generate_overlapping_shapes(size=256):
    img = np.zeros((size, size), dtype=np.uint8)
    cv2.circle(img, (90, 90), 40, 255, -1)
    cv2.rectangle(img, (100, 100), (180, 180), 255, -1)
    cv2.imwrite('overlapping_shapes.png', img)

# Audio: Sine tone + noise
def generate_tone_noise_mix(fs=44100, duration=3):
    t = np.linspace(0, duration, int(fs * duration))
    tone = 0.4 * np.sin(2 * np.pi * 440 * t)
    noise = 0.6 * np.random.normal(0, 1, len(t))
    mix = tone + noise
    write('tone_noise_mix.wav', fs, (mix * 32767 / np.max(np.abs(mix))).astype(np.int16))
